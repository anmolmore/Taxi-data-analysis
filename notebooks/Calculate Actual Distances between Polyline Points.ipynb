# %% [markdown]
# - Anmol More - 11915043
# - Shlok Mittal - 11915071

# %%
import pandas as pd
import numpy as np
import itertools

# %%
df = pd.read_csv('../data/raw/cabdata_v2.csv')

# %%
def EOQ(D):
    l = eval(D)
#     print(l[0])
#     print(l[-1])
    sum = 0
    for first, second in zip(l, l[1:]):
        sum = sum + haversine(first[1], first[0], second[1], second[0])
    return sum

df['distance'] = df.apply(lambda row: EOQ(row['POLYLINE']), axis=1)

# %%
#df['Distance'] = [len(eval(x)) for x in df['POLYLINE']]



def haversine(lat1, lon1, lat2, lon2, to_radians=True, earth_radius=6371):
    """
    slightly modified version: of http://stackoverflow.com/a/29546836/2901002

    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees or in radians)

    All (lat, lon) coordinates must have numeric dtypes and be of equal length.

    """
    if to_radians:
        lat1, lon1, lat2, lon2 = np.radians([lat1, lon1, lat2, lon2])

    a = np.sin((lat2-lat1)/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin((lon2-lon1)/2.0)**2

    return earth_radius * 2 * np.arcsin(np.sqrt(a))

# %%
df.to_csv('../data/raw/cabdata_v5_actual_timings.csv')

# %%
df.sample(10)
# Out:
#          Unnamed: 0 CALL_TYPE DAY_TYPE  MISSING_DATA  ORIGIN_CALL  \
# 147075       149472         B        A         False          NaN
# 750799       764148         B        A         False          NaN
# 261309       265522         A        A         False      18439.0
# 315368       320632         A        A         False       7460.0
# 1597116     1632088         C        A         False          NaN
# 249516       253492         C        A         False          NaN
# 1262186     1289676         B        A         False          NaN
# 435038       442413         B        A         False          NaN
# 223041       226629         B        A         False          NaN
# 112071       113874         C        A         False          NaN
#
#          ORIGIN_STAND                                           POLYLINE  \
# 147075           16.0  [[-8.627778, 41.175387], [-8.627643, 41.175036...
# 750799            9.0  [[-8.606484, 41.144679], [-8.606502, 41.144679...
# ...

# %%
df = pd.read_csv('../data/raw/cabdata_v5_actual_timings.csv')

# %%
pd.isna(df[df['CALL_TYPE'] == 'B']['ORIGIN_STAND']).value_counts()
# Out:
# False    797688
# True      11203
# Name: ORIGIN_STAND, dtype: int64
